# %% [markdown]
# ## **Unidad N° 2 -  Base de datos**:
# ###Contenidos:
# - Tipos de datos (estructurados y no estructurados) y su tratamiento.
# - Limpieza e integración de datos. Técnicas de curación de datos e ingeniería de características (feature engineering).
# - Estandarización de procesos
# - Principios en el manejo de base de datos
# - Bases de datos
# - Uso de Python. Librerías: pandas, numpy, scipy.

# %% [markdown]
# 1.   **Tipos de Datos**
#
# 📌 1. Tipos de datos: estructurados y no estructurados
# Datos estructurados: organizados en tablas con filas y columnas. Ej: bases de datos relacionales, archivos CSV, Excel.
#
# Datos no estructurados: sin formato predefinido. Ej: texto libre, imágenes, audios, videos, publicaciones en redes sociales.
#
# **Importancia**: Identificar el tipo de dato es clave para elegir herramientas y técnicas de procesamiento. En ciencia de datos, muchas veces se combinan ambos.

# %% [markdown]
# -----------
# Antes de realizar cualquier análisis, se debe garantizar que los datos sean confiables.
# Es una etapa crítica del **Data Wrangling** dentro del ciclo de Ciencia de Datos. Es el proceso de tomar datos crudos y transformarlos en un formato limpio, estructurado y utilizable.
# Es como “domesticar los datos” (de ahí la palabra "wrangling", que viene del mundo del rodeo). En la práctica, los datos nunca vienen perfectos: pueden estar incompletos, desordenados, en el formato incorrecto, o tener errores. Data Wrangling es el conjunto de tareas y técnicas que permiten limpiar, transformar y preparar esos datos.
#
# 🧰 Incluye tareas como:
# *   Limpieza de datos
#
# *   Eliminar duplicados
#
# *   Corregir errores tipográficos o de formato
#
# *   Rellenar, eliminar o imputar valores faltantes
#
# *   Conversión de formatos
#
# *   Pasar fechas de string a datetime
#
# *   Convertir columnas categóricas a numéricas (encoding)
#
# *   Filtrado y selección
#
# *   Elegir solo las columnas o filas relevantes
#
# *   Aplicar condiciones para depurar los datos
#
# *   Fusión e integración de fuentes
#
# *   Combinar múltiples datasets
#
# *   Unir información complementaria
#
# *   Transformaciones
#
# *   Crear nuevas variables
#
# *   Escalar o normalizar datos
#
# *   Agrupar o pivotear tablas
#
# *   Otras...

# %% [markdown]
# 🧹 2. Limpieza e integración de datos
# **Limpieza**: detección y corrección de errores (valores faltantes, duplicados, tipos erróneos).
#
# **Integración**: unificación de datos de diferentes fuentes, garantizando coherencia y calidad.

# %% [markdown]
# 🧬 3. Técnicas de curación de datos e ingeniería de características (feature engineering)
# Curación de datos: proceso continuo de mantenimiento y mejora de la calidad de los datos.
#
# Feature engineering: creación, transformación o selección de variables relevantes para modelos analíticos o predictivos.
#
# 👉 Clave: Estas prácticas aumentan el valor de los datos y mejoran la performance de modelos de Machine Learning.

# %% [markdown]
# 📏 4. Estandarización de procesos
# Implica definir y aplicar reglas consistentes para el tratamiento de datos (nombres de columnas, formatos, unidades, etc.).
#
# Mejora la reproducibilidad, escalabilidad y colaboración entre equipos.
#
# 👉 Contexto: En el ciclo de Ciencia de Datos, permite replicar experimentos, construir pipelines robustos y facilitar auditorías.

# %% [markdown]
# 5. Principios en el manejo de bases de datos
# Incluye: normalización, relaciones entre tablas, consultas eficientes, integridad de datos.
#
# Orienta sobre cómo diseñar, consultar y mantener una base de datos relacional o no relacional.
#
# 👉 Relevancia: Una buena base de datos facilita todo el flujo posterior de análisis, visualización y modelado.

# %% [markdown]
# 🧪 6. Uso de Python y librerías principales
# pandas: manipulación de datos tabulares.
#
# *numpy*: operaciones matemáticas eficientes, vectores y matrices.
#
# *scipy*: herramientas científicas y estadísticas.
#
# Estas librerías permiten implementar todo lo anterior: limpieza, transformación, integración y análisis, de forma programática y reproducible.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **3. Preparación de lo datos**

# %% [markdown]
# ![Imagen_1.png](data:image/png;base64,...)

# %% [markdown]
# # **A.** IMPORTACION DE MODULOS.

# %% [markdown]
# # Manipulando Datos con Pandas
#
# <p align="center">
# <img
#      src="https://upload.wikimedia.org/wikipedia/commons/e/ed/Pandas_logo.svg"
#      alt="pypl"
#      width=300
#      height=>
# </p>

# %% [markdown]
# [Pandas](http://pandas.pydata.org) es una biblioteca para manipulación y análisis de datos basada en Numpy. Aporta nuevas estructuras de datos de alto nivel que extienden datos almacenados en arrays, aportando más semántica y nuevas operaciones.
#
# Pandas introduce dos estructuras de datos principales: `Series` y `DataFrame`.

# %%
import pandas as pd

# %% [markdown]
#  https://pandas.pydata.org/docs/

# %%
 pd?

# %% [markdown]
# # **B.** Cargar bases de datos.

# %% [markdown]
# ![Imagen_2.png](data:image/png;base64,...)

# %% [markdown]
# ## **B.1.**  Cargar Bases de Datos localizadas en librerías.

# %% [markdown]
# ### **B.1.1.**  DataFrame estaticos en modulos o librerías.

# %% [markdown]
# **Modulo** "*seaborn*"

# %%
import seaborn as sns

# %% [markdown]
# **Modulo** "*help*"

# %%
help(sns)
# Out:
# Help on package seaborn:
#
# NAME
#     seaborn - # Import seaborn objects
#
# PACKAGE CONTENTS
#     _base
#     _compat
#     _core (package)
#     _docstrings
#     _marks (package)
#     _statistics
#     _stats (package)
#     _testing
#     algorithms
#     axisgrid
#     categorical
#     cm
#     colors (package)
#     distributions
#     external (package)
#     matrix
#     miscplot
#     objects
#     palettes
#     rcmod
#     regression
#     relational
#     utils
#     widgets
#
# DATA
#     crayons = {'Almond': '#EFDECD', 'Antique Brass': '#CD9575', 'Apricot':...
#     xkcd_rgb = {'acid green': '#8ffe09', 'adobe': '#bd6c48', 'algae': '#54...
#
# VERSION
#     0.13.2
#
# FILE
#     /usr/local/lib/python3.11/dist-packages/seaborn/__init__.py

# %% [markdown]
# **Función** "*get_dataset_names()*"

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# **Función** "*load_dataset*"

# %%
df1 = sns.load_dataset("iris")

# %% [markdown]
# **Función** "*info()*"

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# **Metodo** "*objeto.head()*"  Es un método que devuelve las primeras 5 filas del DataFrame de manera predeterminada, del "objeto".
#
# Es muy útil para obtener una vista rápida de los datos, especialmente cuando el DataFrame es grande.

# %%
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %% [markdown]
# **Metodo** "*objeto.tail(#)*"
# ¿Por qué es un método?
# Porque tail se llama a partir de un objeto, en este caso el DataFrame df1. En Python, cuando algo se ejecuta con la sintaxis objeto.método(), se trata de un método, es decir, una función que “vive dentro” del objeto.

# %% [markdown]
# *Devuelve las n últimas filas del DataFrame df1*

# %%
df1.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df1_ult10 = df1.tail(10)
df1_ult10
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df1_ult10 = df1_ult10.reset_index(drop=False)  #Es un método de pandas que reinicia el índice del DataFrame, es decir, vuelve a numerar las filas desde 0, 1, 2, ...
df1_ult10
# Out:
#    index  sepal_length  sepal_width  petal_length  petal_width    species
# 0      0           6.7          3.1           5.6          2.4  virginica
# 1      1           6.9          3.1           5.1          2.3  virginica
# 2      2           5.8          2.7           5.1          1.9  virginica
# 3      3           6.8          3.2           5.9          2.3  virginica
# 4      4           6.7          3.3           5.7          2.5  virginica
# 5      5           6.7          3.0           5.2          2.3  virginica
# 6      6           6.3          2.5           5.0          1.9  virginica
# 7      7           6.5          3.0           5.2          2.0  virginica
# 8      8           6.2          3.4           5.4          2.3  virginica
# 9      9           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# IMPORTANTE!!

# %% [markdown]
# 🎯 **Diferencia clave**:
#
# ✅ Función: Se define a nivel de módulo (por ejemplo, en seaborn), y se llama directamente como sns.get_dataset_names().
#
# ✅ Método: Es una función que está dentro de un objeto o clase, y se llama como *objeto.metodo()*

# %% [markdown]
# ### Identificar elementos de un data frame

# %%
df1['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %% [markdown]
# **Metodo** "*iloc*"

# %% [markdown]
# es un método de pandas que se usa para acceder a elementos del DataFrame por posición, es decir, índices numéricos, no por nombre de filas o columnas. Es decir, obejto.iloc[] se utiliza en los DataFrames para seleccionar los elementos en base a su ubicación.

# %%
df1.iloc[1,1]
# Out:
# 3.0

# %%
df1.iloc[:,[0,1,3]]
# Out:
#      sepal_length  sepal_width  petal_width
# 0             5.1          3.5          0.2
# 1             4.9          3.0          0.2
# 2             4.7          3.2          0.2
# 3             4.6          3.1          0.2
# 4             5.0          3.6          0.2
# ..            ...          ...          ...
# 145           6.7          3.0          2.3
# 146           6.3          2.5          1.9
# 147           6.5          3.0          2.0
# 148           6.2          3.4          2.3
# 149           5.9          3.0          1.8
#
# [150 rows x 3 columns]

# %% [markdown]
# ### Selección por posición

# %%
prueba1 =df1.iloc[:,[0,1,3]]

# %%
prueba1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_width   150 non-null    float64
# dtypes: float64(3)
# memory usage: 3.6 KB

# %%
#df1.iloc[:,[0,1,3]].values
#prueba1.values
# Out:
# array([[5.1, 3.5, 0.2],
#        [4.9, 3. , 0.2],
#        [4.7, 3.2, 0.2],
#        [4.6, 3.1, 0.2],
#        [5. , 3.6, 0.2],
#        [5.4, 3.9, 0.4],
#        [4.6, 3.4, 0.3],
#        [5. , 3.4, 0.2],
#        [4.4, 2.9, 0.2],
#        [4.9, 3.1, 0.1],
#        [5.4, 3.7, 0.2],
#        [4.8, 3.4, 0.2],
#        [4.8, 3. , 0.1],
#        [4.3, 3. , 0.1],
#        [5.8, 4. , 0.2],
#        [5.7, 4.4, 0.4],
#        [5.4, 3.9, 0.4],
#        [5.1, 3.5, 0.3],
#        [5.7, 3.8, 0.3],
#        [5.1, 3.8, 0.3],
#        [5.4, 3.4, 0.2],
#        [5.1, 3.7, 0.4],
#        [4.6, 3.6, 0.2],
#        [5.1, 3.3, 0.5],
#        [4.8, 3.4, 0.2],
#        [5. , 3. , 0.2],
#        [5. , 3.4, 0.4],
#        [5.2, 3.5, 0.2],
#        [5.2, 3.4, 0.2],
#        [4.7, 3.2, 0.2],
#        [4.8, 3.1, 0.2],
#        [5.4, 3.4, 0.4],
#        [5.2, 4.1, 0.1],
#        [5.5, 4.2, 0.2],
#        [4.9, 3.1, 0.2],
#        [5. , 3.2, 0.2],
#        [5.5, 3.5, 0.2],
#        [4.9, 3.6, 0.1],
# ...

# %%
prueba2=df1.iloc[:,[0,1,3]].values

# %%
prueba2.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-66aae08ecb1d> in <cell line: 0>()
# ----> 1 prueba2.info()
#       2 #El método .info() es propio de pandas. Se usa para DataFrames o Series.
#
# AttributeError: 'numpy.ndarray' object has no attribute 'info'

# %%
type(prueba2)
# Out:
# numpy.ndarray

# %% [markdown]
# El método .info() es propio de pandas. Se usa para DataFrames o Series.

# %% [markdown]
# ### **B.1.2.**  DataFrame dinámicos en librerías.

# %% [markdown]
# **Libreria** "*yfinance*"

# %% [markdown]
# **Sistema de gestión de paquetes** "*pip*"

# %%
pip install yfinance

# %%
pip show yfinance
# Out:
# Name: yfinance
# Version: 0.2.55
# Summary: Download market data from Yahoo! Finance API
# Home-page: https://github.com/ranaroussi/yfinance
# Author: Ran Aroussi
# Author-email: ran@aroussi.com
# License: Apache
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: beautifulsoup4, frozendict, multitasking, numpy, pandas, peewee, platformdirs, pytz, requests
# Required-by:

# %%
import yfinance as yf

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df2 = yf.download('AAPL')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
df2
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 1980-12-12    0.098726    0.099155    0.098726    0.098726  469033600
# 1980-12-15    0.093575    0.094005    0.093575    0.094005  175884800
# 1980-12-16    0.086707    0.087136    0.086707    0.087136  105728000
# 1980-12-17    0.088853    0.089282    0.088853    0.088853   86441600
# 1980-12-18    0.091429    0.091858    0.091429    0.091429   73449600
# ...                ...         ...         ...         ...        ...
# 2025-04-08  172.419998  190.339996  169.210007  186.699997  120859500
# 2025-04-09  198.850006  200.610001  171.889999  171.949997  184395900
# 2025-04-10  190.419998  194.779999  183.000000  189.070007  121880000
# 2025-04-11  198.149994  199.539993  186.059998  186.100006   87300000
# 2025-04-14  204.669998  212.940002  201.162094  211.440002   74060885
#
# [11175 rows x 5 columns]

# %%
df2.head()
# Out:
# Price          Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 1980-12-12  0.098726  0.099155  0.098726  0.098726  469033600
# 1980-12-15  0.093575  0.094005  0.093575  0.094005  175884800
# 1980-12-16  0.086707  0.087136  0.086707  0.087136  105728000
# 1980-12-17  0.088853  0.089282  0.088853  0.088853   86441600
# 1980-12-18  0.091429  0.091858  0.091429  0.091429   73449600

# %%
df2.tail()
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2025-04-08  172.419998  190.339996  169.210007  186.699997  120859500
# 2025-04-09  198.850006  200.610001  171.889999  171.949997  184395900
# 2025-04-10  190.419998  194.779999  183.000000  189.070007  121880000
# 2025-04-11  198.149994  199.539993  186.059998  186.100006   87300000
# 2025-04-14  204.669998  212.940002  201.162094  211.440002   74060885

# %%
df2['Volume'].describe()
# Out:
# Ticker          AAPL
# count   1.117500e+04
# mean    3.138868e+08
# std     3.344461e+08
# min     0.000000e+00
# 25%     1.098044e+08
# 50%     2.023616e+08
# 75%     3.941322e+08
# max     7.421641e+09

# %%
plt.plot(df2['Volume'])

# %% [markdown]
# "*arange*" :  Método o función ??

# %%
df2['Orden'] = np.arange(1,len(df2)+1) # Una forma rápida de enumerar las filas de un DataFrame, como si les pusieras un número de orden o índice personalizado.

# %%
df2
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099058
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093890
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086998
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089152
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091736
# ...                ...         ...         ...         ...         ...
# 2024-05-28  191.509995  193.000000  189.100006  189.990005  189.990005
# 2024-05-29  189.610001  192.250000  189.509995  190.289993  190.289993
# 2024-05-30  190.759995  192.179993  190.630005  191.289993  191.289993
# 2024-05-31  191.440002  192.570007  189.910004  192.250000  192.250000
# 2024-06-03  192.899994  194.990005  192.520004  194.029999  194.029999
#
#                Volume  Orden
# Date
# 1980-12-12  469033600      1
# 1980-12-15  175884800      2
# ...

# %% [markdown]
# **np.arange()** es una **función**, no un método.
# Entonces:
#
# ✅ np.arange(...)-> función del módulo numpy.
#
# ✅ len(df2) -> también es una función (nativa de Python).
#
# ✅ df2['Orden'] = ... -> una asignación a una columna.
#
# ✅ df2.info() -> método del DataFrame df2.

# %%
plt.plot(df2['Orden'], df2['Volume'])

# %% [markdown]
# ## **B.2.**  Cargar Bases de Datos localizadas en sitios web.

# %% [markdown]
# **GitHub**
#
# GitHub es una plataforma en línea para almacenar, gestionar y colaborar en proyectos de programación. Está basada en una herramienta llamada Git, que permite llevar un control de versiones del código.
#
# 📌 ¿Qué podés hacer en GitHub?
# Guardar tu código en la nube ☁️
# Subís tus scripts, notebooks, archivos de datos, etc., como si fuera un “Google Drive de proyectos de programación”.
#
# Colaborar con otras personas
#
# Varias personas pueden trabajar juntas en el mismo proyecto, sin pisarse los cambios.
#
# Ver el historial de cambios
# Podés ver qué cambió, cuándo y quién lo hizo. ¡Ideal para trabajo en equipo y para no perder nada!
#
# Compartir proyectos públicamente o en privado
# Muchos proyectos de código abierto están en GitHub. También podés tener repositorios privados.
#
# Conectar con herramientas como Colab o VSCode
# Se integra fácilmente con otras plataformas.
#
# https://github.com/datadista/datasets

# %%
df3 = pd.read_csv("https://raw.githubusercontent.com/AbhiRoy96/Banknote-Authentication-UCI-Dataset/master/bank_notes.csv")

# %%
df3.head()
# Out:
#    variance  skewness  curtosis  entropy  Target
# 0   3.62160    8.6661   -2.8073 -0.44699       0
# 1   4.54590    8.1674   -2.4586 -1.46210       0
# 2   3.86600   -2.6383    1.9242  0.10645       0
# 3   3.45660    9.5228   -4.0112 -3.59440       0
# 4   0.32924   -4.4552    4.5718 -0.98880       0

# %% [markdown]
# Desafío en el aula:
# Si de origen los datos el sopote están .xls:
#  https://cdn.buenosaires.gob.ar/datosabiertos/datasets/ministerio-de-economia-y-finanzas/sueldo-funcionarios/Sueldo_Funcionarios_2024.xlsx
#
#  o .csv
# https://cdn.buenosaires.gob.ar/datosabiertos/datasets/ministerio-de-economia-y-finanzas/sueldo-funcionarios/Sueldo_Funcionarios_2024.csv

# %% [markdown]
# ## **B.3.**  Cargar Bases de Datos localizadas en archivos locales.

# %%
from google.colab import files #Importa el módulo files que forma parte del paquete especial de Colab
uploaded = files.upload() #Abre un cuadro de diálogo para que elijas uno o más archivos de tu computadora y los subas al entorno de Colab
# Out:
#      <input type="file" id="files-c4986874-c244-495e-87e3-dcab70fa0b17" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4986874-c244-495e-87e3-dcab70fa0b17">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Una vez que seleccionás los archivos y se suben, se guardan temporalmente en el entorno, y su contenido queda almacenado en el diccionario *uploaded*

# %% [markdown]
# **Modulo** "*io*"

# %%
import io

# %% [markdown]
# ¿Qué hace el módulo io?
# El módulo io proporciona herramientas para trabajar con flujos de entrada y salida (I/O) en Python, tanto en archivos como en otros tipos de datos (por ejemplo, en memoria). Tiene varias funciones y clases útiles para leer, escribir y manipular datos.

# %%
df4=pd.read_csv(io.BytesIO(uploaded['Sueldo_Funcionarios_2023.csv'])) #
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-80-ddfae7658f87> in <cell line: 0>()
# ----> 1 df4=pd.read_csv(io.BytesIO(uploaded['Sueldo_Funcionarios_2023.csv'])) #
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-e9ae58f210e4> in <cell line: 0>()
# ----> 1 df4
#
# NameError: name 'df4' is not defined

# %%
df4 = pd.read_csv(io.BytesIO(uploaded['Sueldo_Funcionarios_2023.csv']), encoding='ISO-8859-1')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-81-6db2607256d5> in <cell line: 0>()
# ----> 1 df4 = pd.read_csv(io.BytesIO(uploaded['Sueldo_Funcionarios_2023.csv']), encoding='ISO-8859-1')
#
# ...

# %%
df4 = pd.read_csv(io.BytesIO(uploaded['Sueldo_Funcionarios_2023.csv']), encoding='latin1')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-82-aea80ef280f1> in <cell line: 0>()
# ----> 1 df4 = pd.read_csv(io.BytesIO(uploaded['Sueldo_Funcionarios_2023.csv']), encoding='latin1')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# Funciones comunes de io:
# io.BytesIO():
# Crea un buffer en memoria que actúa como si fuera un archivo, pero los datos se almacenan en la memoria en lugar de en el disco. Se usa mucho cuando se manipulan archivos binarios en memoria.
#
# io.StringIO():
# Similar a BytesIO(), pero en lugar de trabajar con datos binarios, se usa para trabajar con cadenas de texto en memoria. Es útil cuando se necesita trabajar con texto como si fuera un archivo.
#
# ectura y escritura en archivos:
# El módulo io también puede ser útil cuando se trabajan con archivos en modo binario o texto, proporcionando más control sobre la codificación y los flujos de datos.

# %%
url = 'http://cdn.buenosaires.gob.ar/datosabiertos/datasets/ministerio-de-economia-y-finanzas/sueldo-funcionarios/Sueldo_Funcionarios_2023.csv'

# Lo almacenamos en una variable llamada salarios
salarios = pd.read_csv( url,
                        encoding='ISO-8859-1', # Esta codificación evita errores con caracteres especiales
                        on_bad_lines="skip", # Omitir líneas problemáticas que podrían interrumpir la carga del archivo
                        sep=";" # Usar el punto y coma (;) como delimitador
                        )

# %%
salarios.head()
# Out:
#             CUIL   AÑO  MES                   AYN                 DESC_REP  \
# 0  27-24483014-0  2023    1  ACUÑA, MARIA SOLEDAD  Ministerio de Educación
# 1  27-24483014-0  2023    2  ACUÑA, MARIA SOLEDAD  Ministerio de Educación
# 2  27-24483014-0  2023    3  ACUÑA, MARIA SOLEDAD  Ministerio de Educación
# 3  27-24483014-0  2023    4  ACUÑA, MARIA SOLEDAD  Ministerio de Educación
# 4  27-24483014-0  2023    5  ACUÑA, MARIA SOLEDAD  Ministerio de Educación
#
#   ASIGNACIÓN POR CARGO\n (I) AGUINALDO (II) TOTAL SALARIO BRUTO\n(I) + (II)  \
# 0             $ 1.226.921,1             NaN                  $ 1.226.921,1
# 1             $ 1.284.795,6             NaN                  $ 1.284.795,6
# 2             $ 1.331.094,9             NaN                  $ 1.331.094,9
# 3             $ 1.446.842,2             NaN                  $ 1.446.842,2
# 4             $ 1.539.439,0             NaN                  $ 1.539.439,0
#
#    OBSERVACIONES
# 0            NaN
# 1            NaN
# ...

# %% [markdown]
# El parámetro url es el que indica el nombre (en este caso la dirección web) del archivo a leer. Los otros parámetros son opcionales y tiene que ver más con el tipo y formato que tienen los datos de este archivo en particular. Pueden ver más información sobre la función read_csv en la documentación oficial de pandas read_csv.

# %% [markdown]
# ## **B.4.**  Crear Bases de Datos desde el cuaderno.

# %% [markdown]
# Diccionarios {}
# Lista []

# %%
datos = {'Rubro': ['Lacteos', 'Bebidas', 'Carnes', 'Verduras', 'Panificados']
         , 'Ventas':[10000, 120000, 15000, 8000, 5000]}

# %%
datos
# Out:
# {'Rubro': ['Lacteos', 'Bebidas', 'Carnes', 'Verduras', 'Panificados'],
#  'Ventas': [10000, 120000, 15000, 8000, 5000]}

# %%
df = pd.DataFrame.from_dict(datos)

# %%
df

# %% [markdown]
# ## **B.5.**  Cargar Bases de Datos localizadas en Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# *   Ubico la carpeta en Google Drive
# *   Botón derecho copio la ruta de acceso a la base de datos

# %%
df5 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Bases de Datos/ahora12_facturacion.xlsx")

# %%
df5.head()
# Out:
#    anio  mes   mes-anio     provincia                rubro A12  Facturacion
# 0  2019    1 2019-01-01  BUENOS AIRES                 Anteojos     30878823
# 1  2019    1 2019-01-01  BUENOS AIRES    Artículos de Librería      4657723
# 2  2019    1 2019-01-01  BUENOS AIRES               Balnearios      5839079
# 3  2019    1 2019-01-01  BUENOS AIRES               Bicicletas     20645150
# 4  2019    1 2019-01-01  BUENOS AIRES  Calzado y Marroquinería    229075801

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19588 entries, 0 to 19587
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   anio         19588 non-null  int64
#  1   mes          19588 non-null  int64
#  2   mes-anio     19588 non-null  datetime64[ns]
#  3   provincia    19588 non-null  object
#  4   rubro A12    19588 non-null  object
#  5   Facturacion  19588 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 918.3+ KB

# %%
df5.dtypes
# Out:
# anio                    int64
# mes                     int64
# mes-anio       datetime64[ns]
# provincia              object
# rubro A12              object
# Facturacion             int64
# dtype: object

# %% [markdown]
# **Metodo** "*describe*"

# %%
df5.describe()

# %%
df5.describe (). apply (lambda s: s.apply (lambda x: format (x, 'f')))
